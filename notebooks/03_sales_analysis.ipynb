# %% [markdown]
# # 03: Sales Performance & Pareto Concentration Intelligence
#
# Analyzes top-line commercial revenue, YoY variance, gross margin health, and 80/20 SKU concentration.

# %%
kpis = compute_executive_kpis(sales_df)
for k, v in kpis.items():
    print(f'{k}: {v}')
# Out:
# total_revenue: 2433028061.72
# total_units: 1033607
# total_cost: 1560073634.78
# total_gross_profit: 872954426.94
# gross_margin_pct: 35.88
# revenue_2024: 1234436018.24
# revenue_2025: 1198592043.48
# yoy_revenue_growth_pct: -2.9
# active_skus: 150
# active_distributors: 20

# %% [markdown]
# ## 80/20 Pareto Concentration Classification

# %%
print(pareto_df['pareto_class'].value_counts())
print(pareto_df.head(5))
# Out:
# pareto_class
# Class C (Bottom 5% Rev)    60
# Class A (Top 80% Rev)      59
# Class B (Next 15% Rev)     31
#
#          sku_id  total_revenue  total_units  total_gross_profit   cum_revenue  cum_revenue_pct           pareto_class
# 0  SKU-BRA-0014    69910741.37        14619         26938921.82  6.991074e+07             2.87  Class A (Top 80% Rev)
# 1  SKU-BRA-0128    67288540.47        14413         23128405.64  1.371993e+08             5.64  Class A (Top 80% Rev)
# 2  SKU-BRA-0147    62550290.64        13917         18071001.96  1.997496e+08             8.21  Class A (Top 80% Rev)
# 3  SKU-BRA-0121    60982799.39        13965         25655678.54  2.607324e+08            10.72  Class A (Top 80% Rev)
# 4  SKU-BRA-0079    60216072.03        13322         20339862.31  3.209484e+08            13.19  Class A (Top 80% Rev)
