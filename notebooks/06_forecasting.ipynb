# %% [markdown]
# # 06: Demand Forecasting & Operational Replenishment
#
# Compares Naive, 4-Week Moving Average, and Simple Exponential Smoothing over a 17-week holdout period to evaluate forecast accuracy.

# %%
print('Holdout Benchmark Summary:')
print(pd.DataFrame(forecast_summary))
print(forecast_df.head(5))
# Out:
# Holdout Benchmark Summary:
#           naive  sma_4  exp_smooth
# MAE       71.76  69.91       69.91
# RMSE      84.59  82.65       82.65
# MAPE_pct  12.52  12.17       12.17
#
#          sku_id week_start_date  actual_demand  forecast_naive  forecast_sma4  forecast_exp_smooth
# 0  SKU-BRA-0002      2025-09-01         1478.4          1410.9         1469.8               1469.8
# 1  SKU-BRA-0002      2025-09-08         1337.1          1410.9         1469.8               1469.8
# 2  SKU-BRA-0002      2025-09-15         1315.3          1410.9         1469.8               1469.8
# 3  SKU-BRA-0002      2025-09-22         1442.6          1410.9         1469.8               1469.8
# 4  SKU-BRA-0002      2025-09-29         1319.9          1410.9         1469.8               1469.8
