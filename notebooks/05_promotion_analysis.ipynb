# %% [markdown]
# # 05: Trade Promotion Effectiveness Analysis
#
# Deconstructs 16 B2B trade marketing campaigns into baseline units, promoted units, concession costs, and Promotion Effectiveness Index (PEI).

# %%
import os, sys, pandas as pd
promos = pd.read_csv('../data/processed/analytical_promotion_effectiveness.csv')
print('Promotion Commercial Classification:')
print(promos['commercial_classification'].value_counts())

# %%
print('Top 5 Promotions by Promotion Effectiveness Index (PEI):')
print(promos[['campaign_name', 'target_category', 'discount_pct', 'observed_units_uplift_pct', 'promotion_effectiveness_index']].head())
