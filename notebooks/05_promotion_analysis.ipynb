# %% [markdown]
# # 05: Trade Marketing Promotion Effectiveness Analysis
#
# Evaluates 16 B2B trade promotion campaigns against de-seasonalized rolling baselines to measure true incremental demand and margin dilution.

# %%
print('Promotion Commercial Classification Breakdown:')
print(promo_eval['commercial_classification'].value_counts())
print(promo_eval[['campaign_name', 'target_category', 'discount_pct', 'observed_units_uplift_pct', 'promotion_effectiveness_index']].head(5))
# Out:
# Promotion Commercial Classification Breakdown:
# commercial_classification
# Value Destructive    16
#
#                                     campaign_name     target_category  discount_pct  observed_units_uplift_pct  promotion_effectiveness_index
# 0       Braking Platinum Tier Loyalty Scheme 2024     Braking Systems          0.05                       5.32                          -0.28
# 1  All-India Fast-Moving Spares Incentive Q1-2024          Filtration          0.06                       3.98                          -0.34
# 2       Braking Platinum Tier Loyalty Scheme 2025     Braking Systems          0.05                       4.01                          -0.38
# 3  All-India Fast-Moving Spares Incentive Q1-2025          Filtration          0.06                       4.01                          -0.40
# 4     Commercial Heavy-Duty Suspension Drive 2024  Chassis & Steering          0.14                     -20.26                          -0.50
