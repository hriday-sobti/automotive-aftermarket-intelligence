# %% [markdown]
# # 04: Inventory & Composite Stockout Risk Analysis
#
# Quantifies wholesale warehouse availability risk using Days of Inventory (DOI), lead-time exposure, and automated safety stock/reorder point formulas.

# %%
print('Stockout Risk Category Breakdown:')
print(risk_df['risk_category'].value_counts())
print(risk_df.head(5))
# Out:
# Stockout Risk Category Breakdown:
# risk_category
# Low Risk    3000
#
#   distributor_id        sku_id                       product_name       product_category  closing_stock  days_of_inventory  daily_sales_velocity  lead_time_days  cv_demand  stockout_risk_score risk_category          primary_risk_driver         recommended_action
# 0        DIST-11  SKU-CHA-0033     Shock Absorber Rear (Standard)     Chassis & Steering             36              171.4                  0.21              39   1.185087                 25.2      Low Risk  Extended Supplier Lead Time  Adequate Inventory Buffer
# 1        DIST-01  SKU-CHA-0104  Suspension Strut Front (Standard)     Chassis & Steering             43              134.4                  0.32              42   0.619539                 24.5      Low Risk  Extended Supplier Lead Time  Adequate Inventory Buffer
# 2        DIST-14  SKU-BRA-0057         Brake Pads Front (Premium)        Braking Systems             93               33.5                  2.78              25   0.616917                 24.5      Low Risk  Extended Supplier Lead Time  Adequate Inventory Buffer
# 3        DIST-03  SKU-ELE-0082      Spark Plug Iridium (Standard)  Electrical & Ignition             69              363.2                  0.19              40   1.081457                 24.1      Low Risk  Extended Supplier Lead Time  Adequate Inventory Buffer
# 4        DIST-02  SKU-CHA-0104  Suspension Strut Front (Standard)     Chassis & Steering            132              400.0                  0.33              42   0.871780                 23.9      Low Risk  Extended Supplier Lead Time  Adequate Inventory Buffer

# %% [markdown]
# ## Safety Stock & Reorder Point Optimization

# %%
print('Reorder Threshold Summary (Safety Stock & ROP):')
print(reorder_df[['safety_stock', 'reorder_point', 'recommended_order_qty']].describe())
# Out:
# Reorder Threshold Summary (Safety Stock & ROP):
#        safety_stock  reorder_point  recommended_order_qty
# count   3000.000000    3000.000000            3000.000000
# mean      26.850333     161.503000             251.141333
# std       32.793288     143.055927             269.109126
# min        0.000000       2.000000               0.000000
# 25%        1.000000      33.000000              13.000000
# 50%       16.000000     143.000000             182.000000
# 75%       43.000000     247.000000             399.250000
# max      195.000000    1250.000000            2508.000000
