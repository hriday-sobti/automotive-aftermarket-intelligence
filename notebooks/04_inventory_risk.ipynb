# %% [markdown]
# # 04: Inventory & Stockout Risk Analysis
#
# Evaluates Days of Inventory (DOI), supplier lead times, composite stockout risk scoring, and safety stock reorder thresholds.

# %%
import os, sys, pandas as pd
risk = pd.read_csv('../data/processed/analytical_inventory_risk_scores.csv')
reorder = pd.read_csv('../data/processed/analytical_reorder_parameters.csv')
print('Risk Category Breakdown:')
print(risk['risk_category'].value_counts())

# %%
print('Top 5 Stockout Risk SKUs:')
print(risk.head())

# %%
print('Reorder Threshold Summary:')
print(reorder[['safety_stock', 'reorder_point', 'recommended_order_qty']].describe())
