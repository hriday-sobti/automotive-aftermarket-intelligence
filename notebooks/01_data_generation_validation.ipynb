# %% [markdown]
# # 01: Data Generation & Pre-Flight Validation
#
# Generates synthetic dimensions, demand, promotions, sales, and inventory, followed by automated pre-flight integrity audits.

# %%
import os, sys, pandas as pd
sys.path.insert(0, os.path.abspath('..'))
from src.utils.config_utils import load_config
from src.validation.validator import DataValidator
config = load_config('../config/project_config.yaml')
print('Config loaded:', config['project']['name'])

# %%
report = pd.read_csv('../data/interim/data_validation_report.csv')
print('Validation Audit Report:')
print(report.to_string())
