# %% [markdown]
# # 01: Synthetic Data Generation & Pre-Flight Validation
#
# This notebook demonstrates the synthetic data generation pipeline, entity configurations, and automated pre-flight mathematical assertions.

# %%
import pandas as pd
from src.utils.config_utils import load_config
config = load_config()
print(f"Project: {config['project']['name']}")
print(f"Timeline: {config['timeline']['start_date']} to {config['timeline']['end_date']}")
print(f"Random Seed: {config['project']['random_seed']}")
# Out:
# Project: Automotive Aftermarket Sales & Trade Marketing Intelligence Platform
# Timeline: 2024-01-01 to 2025-12-31
# Random Seed: 42

# %% [markdown]
# ## Automated Pre-Flight Integrity Audit
#
# Verifies primary key uniqueness, foreign key relationships, revenue reconciliation, gross profit reconciliation, and mass stock flow balance.

# %%
report = pd.read_csv('../data/interim/data_validation_report.csv')
print(report.to_string())
# Out:
#                  table                                                      check status                                                              details
# 0           dim_region                       PK Uniqueness & Non-Null (region_id)   PASS                         Total rows: 4, Unique region_id: 4, Nulls: 0
# 1  dim_vehicle_segment                      PK Uniqueness & Non-Null (segment_id)   PASS                        Total rows: 4, Unique segment_id: 4, Nulls: 0
# 2          dim_product                          PK Uniqueness & Non-Null (sku_id)   PASS                        Total rows: 150, Unique sku_id: 150, Nulls: 0
# 3      dim_distributor                  PK Uniqueness & Non-Null (distributor_id)   PASS                  Total rows: 20, Unique distributor_id: 20, Nulls: 0
# 4         dim_workshop                     PK Uniqueness & Non-Null (workshop_id)   PASS                   Total rows: 120, Unique workshop_id: 120, Nulls: 0
# 5             dim_date                            PK Uniqueness & Non-Null (date)   PASS                          Total rows: 731, Unique date: 731, Nulls: 0
# 6           FACT_SALES                 Sales Financial & Integrity Reconciliation   PASS                         Total rows: 88659, Valid: 88659, Rejected: 0
# 7       FACT_INVENTORY  Stock Flow Balance (Closing == Opening + Receipts - Sold)   PASS  Total records: 314934, Balanced: 314934, Non-negative closing: True
